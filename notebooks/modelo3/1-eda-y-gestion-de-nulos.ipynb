# %%
# Para no tener que reiniciar el kernel
# %load_ext autoreload
# %autoreload 2

# Tratamiento de datos
# -----------------------------------------------------------------------
import numpy as np
import pandas as pd
import pickle

# Otros objetivos
# -----------------------------------------------------------------------
import math

# Gráficos
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt

from itertools import product, combinations
from sklearn.preprocessing import MinMaxScaler, Normalizer, StandardScaler, RobustScaler
from sklearn.neighbors import LocalOutlierFactor # para detectar outliers usando el método LOF
from sklearn.ensemble import IsolationForest # para detectar outliers usando el metodo IF

# Para imputar nulos
# -------------------------------------------------------------------------
from sklearn.experimental import enable_iterative_imputer  # Habilita IterativeImputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# Para tratar el problema de desbalance
# -----------------------------------------------------------------------
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTETomek

from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, LabelEncoder #, TargetEncoder # para poder aplicar los métodos de OneHot, Ordinal,  Label y Target Encoder 

from category_encoders import TargetEncoder
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("../../")

# %%
# Insertamos los soportes de nuestro src
from src import soporte_preprocesamiento as sp
from src import soporte_encoding as se
from src import soporte_logistica_preprocesamiento as slp

# %%
# Instrucción para visualizar todas las columnas de un dataFrame
pd.set_option('display.max_columns', None)

# %%
df_datos_generales = pd.read_csv('../../datos/origen/general_data.csv')
df_survey_empleados = pd.read_csv('../../datos/origen/employee_survey_data.csv')
df_survey_managers = pd.read_csv('../../datos/origen/manager_survey_data.csv')

# %%
df_datos_generales.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# 0          2  Life Sciences              1           1  Female         1
# 1          1  Life Sciences              1           2  Female         1
# 2          4          Other              1           3    Male         4
# 3          5  Life Sciences              1           4    Male         3
# 4          1        Medical              1           5    Male         1
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 0  Healthcare Representative       Married         131160                 1.0
# 1         Research Scientist        Single          41890                 0.0
# 2            Sales Executive       Married         193280                 1.0
# 3            Human Resources       Married          83210                 3.0
# 4            Sales Executive        Single          23420                 4.0
#
#   Over18  PercentSalaryHike  StandardHours  StockOptionLevel  \
# 0      Y                 11              8                 0
# 1      Y                 23              8                 1
# 2      Y                 15              8                 3
# 3      Y                 11              8                 3
# 4      Y                 12              8                 2
#
#    TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                1.0                      6               1
# 1                6.0                      3               5
# 2                5.0                      2               5
# 3               13.0                      5               8
# 4                9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        1                     4
# 2                        0                     3
# 3                        7                     5
# 4                        0                     4

# %%
df_datos_generales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
#  14  NumCompaniesWorked       4391 non-null   float64
#  15  Over18                   4410 non-null   object
#  16  PercentSalaryHike        4410 non-null   int64
#  17  StandardHours            4410 non-null   int64
#  18  StockOptionLevel         4410 non-null   int64
#  19  TotalWorkingYears        4401 non-null   float64
#  20  TrainingTimesLastYear    4410 non-null   int64
#  21  YearsAtCompany           4410 non-null   int64
#  22  YearsSinceLastPromotion  4410 non-null   int64
#  23  YearsWithCurrManager     4410 non-null   int64
# dtypes: float64(2), int64(14), object(8)
# memory usage: 827.0+ KB

# %%
df_survey_empleados.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0

# %%
df_survey_empleados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   EnvironmentSatisfaction  4385 non-null   float64
#  2   JobSatisfaction          4390 non-null   float64
#  3   WorkLifeBalance          4372 non-null   float64
# dtypes: float64(3), int64(1)
# memory usage: 137.9 KB

# %%
df_survey_managers.head()
# Out:
#    EmployeeID  JobInvolvement  PerformanceRating
# 0           1               3                  3
# 1           2               2                  4
# 2           3               3                  3
# 3           4               2                  3
# 4           5               3                  3

# %%
df_survey_managers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EmployeeID         4410 non-null   int64
#  1   JobInvolvement     4410 non-null   int64
#  2   PerformanceRating  4410 non-null   int64
# dtypes: int64(3)
# memory usage: 103.5 KB

# %% [markdown]
# Los tres dataframes tienen el mismo número de filas y tiennen en común una columna llamada EmployeeID. Así que, vamos a unir los tres dataframes en uno solo tomando EmployeeID como columna común de referencia

# %%
df_aux = pd.merge(df_survey_empleados, df_datos_generales, on="EmployeeID", how="inner")
df = pd.merge(df_aux, df_survey_managers, on="EmployeeID", how="inner")

# %%
df.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  Age  \
# 0           1                      3.0              4.0              2.0   51
# 1           2                      3.0              2.0              4.0   31
# 2           3                      2.0              2.0              1.0   32
# 3           4                      4.0              4.0              3.0   38
# 4           5                      4.0              1.0              3.0   32
#
#   Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0        No      Travel_Rarely                   Sales                 6
# 1       Yes  Travel_Frequently  Research & Development                10
# 2        No  Travel_Frequently  Research & Development                17
# 3        No         Non-Travel  Research & Development                 2
# 4        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  Gender  JobLevel  \
# 0          2  Life Sciences              1  Female         1
# 1          1  Life Sciences              1  Female         1
# 2          4          Other              1    Male         4
# 3          5  Life Sciences              1    Male         3
# 4          1        Medical              1    Male         1
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 0  Healthcare Representative       Married         131160                 1.0
# 1         Research Scientist        Single          41890                 0.0
# 2            Sales Executive       Married         193280                 1.0
# 3            Human Resources       Married          83210                 3.0
# 4            Sales Executive        Single          23420                 4.0
#
#   Over18  PercentSalaryHike  StandardHours  StockOptionLevel  \
# 0      Y                 11              8                 0
# 1      Y                 23              8                 1
# 2      Y                 15              8                 3
# 3      Y                 11              8                 3
# 4      Y                 12              8                 2
#
#    TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                1.0                      6               1
# 1                6.0                      3               5
# 2                5.0                      2               5
# 3               13.0                      5               8
# 4                9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager  JobInvolvement  \
# 0                        0                     0               3
# 1                        1                     4               2
# 2                        0                     3               3
# 3                        7                     5               2
# 4                        0                     4               3
#
#    PerformanceRating
# 0                  3
# 1                  4
# 2                  3
# 3                  3
# 4                  3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   EnvironmentSatisfaction  4385 non-null   float64
#  2   JobSatisfaction          4390 non-null   float64
#  3   WorkLifeBalance          4372 non-null   float64
#  4   Age                      4410 non-null   int64
#  5   Attrition                4410 non-null   object
#  6   BusinessTravel           4410 non-null   object
#  7   Department               4410 non-null   object
#  8   DistanceFromHome         4410 non-null   int64
#  9   Education                4410 non-null   int64
#  10  EducationField           4410 non-null   object
#  11  EmployeeCount            4410 non-null   int64
#  12  Gender                   4410 non-null   object
#  13  JobLevel                 4410 non-null   int64
#  14  JobRole                  4410 non-null   object
#  15  MaritalStatus            4410 non-null   object
#  16  MonthlyIncome            4410 non-null   int64
#  17  NumCompaniesWorked       4391 non-null   float64
#  18  Over18                   4410 non-null   object
#  19  PercentSalaryHike        4410 non-null   int64
#  20  StandardHours            4410 non-null   int64
#  21  StockOptionLevel         4410 non-null   int64
#  22  TotalWorkingYears        4401 non-null   float64
#  23  TrainingTimesLastYear    4410 non-null   int64
#  24  YearsAtCompany           4410 non-null   int64
#  25  YearsSinceLastPromotion  4410 non-null   int64
#  26  YearsWithCurrManager     4410 non-null   int64
#  27  JobInvolvement           4410 non-null   int64
#  28  PerformanceRating        4410 non-null   int64
# dtypes: float64(5), int64(16), object(8)
# memory usage: 999.3+ KB

# %% [markdown]
# Vamos a convertir la Variable Respuesta Attrition en numérica.

# %%
diccionario_vr={"No":0,
                  "Yes":1}
df["Attrition"]=df["Attrition"].map(diccionario_vr)

# %% [markdown]
# Hemos unido los tres dataframes correctamente, procedemos a hacer el eda

# %%
sp.exploracion_datos(df)
# Out:
# El número de filas es 4410 y el número de columnas es 29
#
# ----------
#
# En este conjunto de datos tenemos 0 valores duplicados
#
# ----------
#
# Los columnas con valores nulos y sus porcentajes son:
# EnvironmentSatisfaction    0.566893
# JobSatisfaction            0.453515
# WorkLifeBalance            0.861678
# NumCompaniesWorked         0.430839
# TotalWorkingYears          0.204082
# dtype: float64
# ----------
#
# Las principales estadísticas de las variables númericas son:
#                           count          mean           std      min  \
# EmployeeID               4410.0   2205.500000   1273.201673      1.0
# EnvironmentSatisfaction  4385.0      2.723603      1.092756      1.0
# JobSatisfaction          4390.0      2.728246      1.101253      1.0
# WorkLifeBalance          4372.0      2.761436      0.706245      1.0
# Age                      4410.0     36.923810      9.133301     18.0
# Attrition                4410.0      0.161224      0.367780      0.0
# DistanceFromHome         4410.0      9.192517      8.105026      1.0
# Education                4410.0      2.912925      1.023933      1.0
# EmployeeCount            4410.0      1.000000      0.000000      1.0
# JobLevel                 4410.0      2.063946      1.106689      1.0
# MonthlyIncome            4410.0  65029.312925  47068.888559  10090.0
# NumCompaniesWorked       4391.0      2.694830      2.498887      0.0
# PercentSalaryHike        4410.0     15.209524      3.659108     11.0
# StandardHours            4410.0      8.000000      0.000000      8.0
# StockOptionLevel         4410.0      0.793878      0.851883      0.0
# TotalWorkingYears        4401.0     11.279936      7.782222      0.0
# TrainingTimesLastYear    4410.0      2.799320      1.288978      0.0
# YearsAtCompany           4410.0      7.008163      6.125135      0.0
# YearsSinceLastPromotion  4410.0      2.187755      3.221699      0.0
# YearsWithCurrManager     4410.0      4.123129      3.567327      0.0
# JobInvolvement           4410.0      2.729932      0.711400      1.0
# PerformanceRating        4410.0      3.153741      0.360742      3.0
#
#                               25%      50%       75%       max
# EmployeeID                1103.25   2205.5   3307.75    4410.0
# EnvironmentSatisfaction      2.00      3.0      4.00       4.0
# JobSatisfaction              2.00      3.0      4.00       4.0
# WorkLifeBalance              2.00      3.0      3.00       4.0
# Age                         30.00     36.0     43.00      60.0
# Attrition                    0.00      0.0      0.00       1.0
# DistanceFromHome             2.00      7.0     14.00      29.0
# Education                    2.00      3.0      4.00       5.0
# EmployeeCount                1.00      1.0      1.00       1.0
# JobLevel                     1.00      2.0      3.00       5.0
# MonthlyIncome            29110.00  49190.0  83800.00  199990.0
# NumCompaniesWorked           1.00      2.0      4.00       9.0
# PercentSalaryHike           12.00     14.0     18.00      25.0
# StandardHours                8.00      8.0      8.00       8.0
# StockOptionLevel             0.00      1.0      1.00       3.0
# TotalWorkingYears            6.00     10.0     15.00      40.0
# TrainingTimesLastYear        2.00      3.0      3.00       6.0
# YearsAtCompany               3.00      5.0      9.00      40.0
# YearsSinceLastPromotion      0.00      1.0      3.00      15.0
# YearsWithCurrManager         2.00      3.0      7.00      17.0
# JobInvolvement               2.00      3.0      3.00       4.0
# PerformanceRating            3.00      3.0      3.00       4.0
# ----------
#
# Las principales estadísticas de las variables categóricas son:
#                count unique                     top  freq
# BusinessTravel  4410      3           Travel_Rarely  3129
# Department      4410      3  Research & Development  2883
# EducationField  4410      6           Life Sciences  1818
# Gender          4410      2                    Male  2646
# JobRole         4410      9         Sales Executive   978
# MaritalStatus   4410      3                 Married  2019
# Over18          4410      1                       Y  4410
# ----------
#
# Las características principales del dataframe son:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   EnvironmentSatisfaction  4385 non-null   float64
#  2   JobSatisfaction          4390 non-null   float64
#  3   WorkLifeBalance          4372 non-null   float64
#  4   Age                      4410 non-null   int64
#  5   Attrition                4410 non-null   int64
#  6   BusinessTravel           4410 non-null   object
#  7   Department               4410 non-null   object
#  8   DistanceFromHome         4410 non-null   int64
#  9   Education                4410 non-null   int64
#  10  EducationField           4410 non-null   object
#  11  EmployeeCount            4410 non-null   int64
#  12  Gender                   4410 non-null   object
#  13  JobLevel                 4410 non-null   int64
#  14  JobRole                  4410 non-null   object
#  15  MaritalStatus            4410 non-null   object
#  16  MonthlyIncome            4410 non-null   int64
#  17  NumCompaniesWorked       4391 non-null   float64
#  18  Over18                   4410 non-null   object
#  19  PercentSalaryHike        4410 non-null   int64
#  20  StandardHours            4410 non-null   int64
#  21  StockOptionLevel         4410 non-null   int64
#  22  TotalWorkingYears        4401 non-null   float64
#  23  TrainingTimesLastYear    4410 non-null   int64
#  24  YearsAtCompany           4410 non-null   int64
#  25  YearsSinceLastPromotion  4410 non-null   int64
#  26  YearsWithCurrManager     4410 non-null   int64
#  27  JobInvolvement           4410 non-null   int64
#  28  PerformanceRating        4410 non-null   int64
# dtypes: float64(5), int64(17), object(7)
# memory usage: 999.3+ KB
# None

# %% [markdown]
# No tenemos duplicados, pero si que tenemos nulos que tratar, en todo caso ninguna de las columnas llega al 1 por ciento de nulos.

# %%
# Identificamos y mostramos las columnas que toman un único valor
columnas_univalor = [col for col in df.columns if df[col].nunique() == 1]
columnas_univalor
# Out:
# ['EmployeeCount', 'Over18', 'StandardHours']

# %% [markdown]
# Estas tres variables toman un único valor,  y ni que el numero de empleadores sea 1 ni el que todos sean mayores que 18 ni que el numero de horas trabajadas sea siempre 8 aporta valor al modelo predictivo por tanto eliminamos esas columnas.

# %% [markdown]
# "EmployeeID" nos ha servido como columna de referencia en la unión, pero a efectos del analisis predictivo es una columna irrelevante, así que la eliminamos también.

# %%
df.drop(columns=['EmployeeCount', 'Over18', 'StandardHours','EmployeeID'], inplace=True)

# %% [markdown]
# Ahora que hemos eliminado estas columnas, volvemos a pasar la función del EDA.

# %%
sp.exploracion_datos(df)
# Out:
# El número de filas es 4410 y el número de columnas es 25
#
# ----------
#
# En este conjunto de datos tenemos 2837 valores duplicados
#
# ----------
#
# Los columnas con valores nulos y sus porcentajes son:
# EnvironmentSatisfaction    0.566893
# JobSatisfaction            0.453515
# WorkLifeBalance            0.861678
# NumCompaniesWorked         0.430839
# TotalWorkingYears          0.204082
# dtype: float64
# ----------
#
# Las principales estadísticas de las variables númericas son:
#                           count          mean           std      min      25%  \
# EnvironmentSatisfaction  4385.0      2.723603      1.092756      1.0      2.0
# JobSatisfaction          4390.0      2.728246      1.101253      1.0      2.0
# WorkLifeBalance          4372.0      2.761436      0.706245      1.0      2.0
# Age                      4410.0     36.923810      9.133301     18.0     30.0
# Attrition                4410.0      0.161224      0.367780      0.0      0.0
# DistanceFromHome         4410.0      9.192517      8.105026      1.0      2.0
# Education                4410.0      2.912925      1.023933      1.0      2.0
# JobLevel                 4410.0      2.063946      1.106689      1.0      1.0
# MonthlyIncome            4410.0  65029.312925  47068.888559  10090.0  29110.0
# NumCompaniesWorked       4391.0      2.694830      2.498887      0.0      1.0
# PercentSalaryHike        4410.0     15.209524      3.659108     11.0     12.0
# StockOptionLevel         4410.0      0.793878      0.851883      0.0      0.0
# TotalWorkingYears        4401.0     11.279936      7.782222      0.0      6.0
# TrainingTimesLastYear    4410.0      2.799320      1.288978      0.0      2.0
# YearsAtCompany           4410.0      7.008163      6.125135      0.0      3.0
# YearsSinceLastPromotion  4410.0      2.187755      3.221699      0.0      0.0
# YearsWithCurrManager     4410.0      4.123129      3.567327      0.0      2.0
# JobInvolvement           4410.0      2.729932      0.711400      1.0      2.0
# PerformanceRating        4410.0      3.153741      0.360742      3.0      3.0
#
#                              50%      75%       max
# EnvironmentSatisfaction      3.0      4.0       4.0
# JobSatisfaction              3.0      4.0       4.0
# WorkLifeBalance              3.0      3.0       4.0
# Age                         36.0     43.0      60.0
# Attrition                    0.0      0.0       1.0
# DistanceFromHome             7.0     14.0      29.0
# Education                    3.0      4.0       5.0
# JobLevel                     2.0      3.0       5.0
# MonthlyIncome            49190.0  83800.0  199990.0
# NumCompaniesWorked           2.0      4.0       9.0
# PercentSalaryHike           14.0     18.0      25.0
# StockOptionLevel             1.0      1.0       3.0
# TotalWorkingYears           10.0     15.0      40.0
# TrainingTimesLastYear        3.0      3.0       6.0
# YearsAtCompany               5.0      9.0      40.0
# YearsSinceLastPromotion      1.0      3.0      15.0
# YearsWithCurrManager         3.0      7.0      17.0
# JobInvolvement               3.0      3.0       4.0
# PerformanceRating            3.0      3.0       4.0
# ----------
#
# Las principales estadísticas de las variables categóricas son:
#                count unique                     top  freq
# BusinessTravel  4410      3           Travel_Rarely  3129
# Department      4410      3  Research & Development  2883
# EducationField  4410      6           Life Sciences  1818
# Gender          4410      2                    Male  2646
# JobRole         4410      9         Sales Executive   978
# MaritalStatus   4410      3                 Married  2019
# ----------
#
# Las características principales del dataframe son:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EnvironmentSatisfaction  4385 non-null   float64
#  1   JobSatisfaction          4390 non-null   float64
#  2   WorkLifeBalance          4372 non-null   float64
#  3   Age                      4410 non-null   int64
#  4   Attrition                4410 non-null   int64
#  5   BusinessTravel           4410 non-null   object
#  6   Department               4410 non-null   object
#  7   DistanceFromHome         4410 non-null   int64
#  8   Education                4410 non-null   int64
#  9   EducationField           4410 non-null   object
#  10  Gender                   4410 non-null   object
#  11  JobLevel                 4410 non-null   int64
#  12  JobRole                  4410 non-null   object
#  13  MaritalStatus            4410 non-null   object
#  14  MonthlyIncome            4410 non-null   int64
#  15  NumCompaniesWorked       4391 non-null   float64
#  16  PercentSalaryHike        4410 non-null   int64
#  17  StockOptionLevel         4410 non-null   int64
#  18  TotalWorkingYears        4401 non-null   float64
#  19  TrainingTimesLastYear    4410 non-null   int64
#  20  YearsAtCompany           4410 non-null   int64
#  21  YearsSinceLastPromotion  4410 non-null   int64
#  22  YearsWithCurrManager     4410 non-null   int64
#  23  JobInvolvement           4410 non-null   int64
#  24  PerformanceRating        4410 non-null   int64
# dtypes: float64(5), int64(14), object(6)
# memory usage: 861.5+ KB
# None

# %% [markdown]
# Observamos que tenemos 2837 duplicados. Es decir, tenemos 2837 empleados que una vez eliminado el ID tienen todas las características iguales. Eliminamos los duplicados.

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %% [markdown]
# De nuevo, invocamos a la función del EDA, para analizar el dataframe después de haber eliminado dupliados.

# %%
sp.exploracion_datos(df)
# Out:
# El número de filas es 1573 y el número de columnas es 25
#
# ----------
#
# En este conjunto de datos tenemos 0 valores duplicados
#
# ----------
#
# Los columnas con valores nulos y sus porcentajes son:
# EnvironmentSatisfaction    1.462174
# JobSatisfaction            1.144310
# WorkLifeBalance            2.225048
# NumCompaniesWorked         1.207883
# TotalWorkingYears          0.572155
# dtype: float64
# ----------
#
# Las principales estadísticas de las variables númericas son:
#                           count          mean           std      min      25%  \
# EnvironmentSatisfaction  1550.0      2.718065      1.090423      1.0      2.0
# JobSatisfaction          1555.0      2.737621      1.100763      1.0      2.0
# WorkLifeBalance          1538.0      2.761378      0.701994      1.0      2.0
# Age                      1573.0     36.904005      9.105911     18.0     30.0
# Attrition                1573.0      0.160203      0.366911      0.0      0.0
# DistanceFromHome         1573.0      9.158296      8.124414      1.0      2.0
# Education                1573.0      2.911634      1.022867      1.0      2.0
# JobLevel                 1573.0      2.056580      1.108022      1.0      1.0
# MonthlyIncome            1573.0  64979.459631  47121.739301  10090.0  28990.0
# NumCompaniesWorked       1554.0      2.703990      2.508432      0.0      1.0
# PercentSalaryHike        1573.0     15.202161      3.646403     11.0     12.0
# StockOptionLevel         1573.0      0.790210      0.848876      0.0      0.0
# TotalWorkingYears        1564.0     11.245524      7.748763      0.0      6.0
# TrainingTimesLastYear    1573.0      2.807374      1.287203      0.0      2.0
# YearsAtCompany           1573.0      6.970757      6.068348      0.0      3.0
# YearsSinceLastPromotion  1573.0      2.184361      3.203105      0.0      0.0
# YearsWithCurrManager     1573.0      4.102988      3.572701      0.0      2.0
# JobInvolvement           1573.0      2.732994      0.712421      1.0      2.0
# PerformanceRating        1573.0      3.152575      0.359691      3.0      3.0
#
#                              50%      75%       max
# EnvironmentSatisfaction      3.0      4.0       4.0
# JobSatisfaction              3.0      4.0       4.0
# WorkLifeBalance              3.0      3.0       4.0
# Age                         36.0     43.0      60.0
# Attrition                    0.0      0.0       1.0
# DistanceFromHome             7.0     14.0      29.0
# Education                    3.0      4.0       5.0
# JobLevel                     2.0      3.0       5.0
# MonthlyIncome            49000.0  83800.0  199990.0
# NumCompaniesWorked           2.0      4.0       9.0
# PercentSalaryHike           14.0     18.0      25.0
# StockOptionLevel             1.0      1.0       3.0
# TotalWorkingYears           10.0     15.0      40.0
# TrainingTimesLastYear        3.0      3.0       6.0
# YearsAtCompany               5.0      9.0      40.0
# YearsSinceLastPromotion      1.0      3.0      15.0
# YearsWithCurrManager         3.0      7.0      17.0
# JobInvolvement               3.0      3.0       4.0
# PerformanceRating            3.0      3.0       4.0
# ----------
#
# Las principales estadísticas de las variables categóricas son:
#                count unique                     top  freq
# BusinessTravel  1573      3           Travel_Rarely  1117
# Department      1573      3  Research & Development  1030
# EducationField  1573      6           Life Sciences   655
# Gender          1573      2                    Male   953
# JobRole         1573      9         Sales Executive   348
# MaritalStatus   1573      3                 Married   720
# ----------
#
# Las características principales del dataframe son:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EnvironmentSatisfaction  1550 non-null   float64
#  1   JobSatisfaction          1555 non-null   float64
#  2   WorkLifeBalance          1538 non-null   float64
#  3   Age                      1573 non-null   int64
#  4   Attrition                1573 non-null   int64
#  5   BusinessTravel           1573 non-null   object
#  6   Department               1573 non-null   object
#  7   DistanceFromHome         1573 non-null   int64
#  8   Education                1573 non-null   int64
#  9   EducationField           1573 non-null   object
#  10  Gender                   1573 non-null   object
#  11  JobLevel                 1573 non-null   int64
#  12  JobRole                  1573 non-null   object
#  13  MaritalStatus            1573 non-null   object
#  14  MonthlyIncome            1573 non-null   int64
#  15  NumCompaniesWorked       1554 non-null   float64
#  16  PercentSalaryHike        1573 non-null   int64
#  17  StockOptionLevel         1573 non-null   int64
#  18  TotalWorkingYears        1564 non-null   float64
#  19  TrainingTimesLastYear    1573 non-null   int64
#  20  YearsAtCompany           1573 non-null   int64
#  21  YearsSinceLastPromotion  1573 non-null   int64
#  22  YearsWithCurrManager     1573 non-null   int64
#  23  JobInvolvement           1573 non-null   int64
#  24  PerformanceRating        1573 non-null   int64
# dtypes: float64(5), int64(14), object(6)
# memory usage: 307.4+ KB
# None

# %% [markdown]
# Nos hemos quedado on 1573 valores en el Dataframe

# %% [markdown]
# ### VISUALIZACIÓN DE NUMÉRICAS Y CATEGÓRICAS

# %%
visualizador = sp.Visualizador(df)

# %%
visualizador.plot_numericas(color="blue", tamano_grafica=(20, 15))

# %%
visualizador.plot_categoricas()

# %% [markdown]
# ### NULOS

# %% [markdown]
# Tenemos 5 columnas con nulos: NumCompaniesWorked, TotalWorkingYears, EnvironmentSatisfaction, JobSatisfaction,WorkLifeBalance, vamos a imputarlas con IterativeImputer usando la mediana como estadístico.

# %%
df_numericas=df.select_dtypes(include=np.number)
imputer_iterative = IterativeImputer(initial_strategy='median')
iterative_imputado= imputer_iterative.fit_transform(df_numericas)
df_numericas_sin_nulos = pd.DataFrame(iterative_imputado, columns=df_numericas.columns)
df[df_numericas.columns]= df_numericas_sin_nulos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EnvironmentSatisfaction  1573 non-null   float64
#  1   JobSatisfaction          1573 non-null   float64
#  2   WorkLifeBalance          1573 non-null   float64
#  3   Age                      1573 non-null   float64
#  4   Attrition                1573 non-null   float64
#  5   BusinessTravel           1573 non-null   object
#  6   Department               1573 non-null   object
#  7   DistanceFromHome         1573 non-null   float64
#  8   Education                1573 non-null   float64
#  9   EducationField           1573 non-null   object
#  10  Gender                   1573 non-null   object
#  11  JobLevel                 1573 non-null   float64
#  12  JobRole                  1573 non-null   object
#  13  MaritalStatus            1573 non-null   object
#  14  MonthlyIncome            1573 non-null   float64
#  15  NumCompaniesWorked       1573 non-null   float64
#  16  PercentSalaryHike        1573 non-null   float64
#  17  StockOptionLevel         1573 non-null   float64
#  18  TotalWorkingYears        1573 non-null   float64
#  19  TrainingTimesLastYear    1573 non-null   float64
#  20  YearsAtCompany           1573 non-null   float64
#  21  YearsSinceLastPromotion  1573 non-null   float64
#  22  YearsWithCurrManager     1573 non-null   float64
#  23  JobInvolvement           1573 non-null   float64
#  24  PerformanceRating        1573 non-null   float64
# dtypes: float64(19), object(6)
# memory usage: 307.4+ KB

# %% [markdown]
# ### FORMATEO DE COLUMNAS

# %% [markdown]
# Redondeamos columnas que quedaron con decimales al pasar por el IterativeImputer

# %%
df['EnvironmentSatisfaction'] = df['EnvironmentSatisfaction'].round()
df["TotalWorkingYears"]=df["TotalWorkingYears"].round()
df['NumCompaniesWorked']=df['NumCompaniesWorked'].round()
df["JobSatisfaction"]=df["JobSatisfaction"].round()
df["JobInvolvement"]=df["JobInvolvement"].round()
df["WorkLifeBalance"]=df["WorkLifeBalance"].round()
df["NumCompaniesWorked"]=df["NumCompaniesWorked"].round()

# %%
columnas_a_convertir = ["Education", "JobLevel", "StockOptionLevel",
                      "TrainingTimesLastYear", "EnvironmentSatisfaction", "JobSatisfaction",
                      "WorkLifeBalance", "JobInvolvement"]

df[columnas_a_convertir] = df[columnas_a_convertir].astype('object')

# %% [markdown]
# Pasamos el MONTHLYINCOME de Rupias a Euros usando la tasa de conversión actual (a fecha de 29/11/2024): 1 Rupia = 0,011 EUR

# %%
df["MonthlyIncome"]=df["MonthlyIncome"].apply(lambda x: x * 0.011)

# %% [markdown]
# A la variable "Education" le mapeamos los valores de texto que vienen en diccionario-datos.

# %% [markdown]
# diccionario_educacion={1 :'Below College',
# 2 :'College',
# 3 :'Bachelor',
# 4 :'Master',
# 5 :'Doctor'}
#
# df["Education"]=df["Education"].map(diccionario_educacion)

# %% [markdown]
# Redondeamos los valores de EnvironmentSatisfaction al entero más cercano (se generaron decimales al pasar por Iterative Imputer) y mapeamos con los valores de texto que nos indica diccionario-datos

# %%
df['EnvironmentSatisfaction'].value_counts()
# Out:
# EnvironmentSatisfaction
# 3.0    505
# 4.0    465
# 2.0    304
# 1.0    299
# Name: count, dtype: int64

# %%
diccionario_environment={1 :'Low',
2 :'Medium',
3 :'High',
4 :'Very High'}

df["EnvironmentSatisfaction"]=df["EnvironmentSatisfaction"].map(diccionario_environment)

# %% [markdown]
# Redondeamos TotalWorkingYears y NumCompaniesWorked para que tenga enteros como tenía antes del pasarle el Iterative Impute

# %% [markdown]
# Formateamos JobInvolvement con los valores de texto de diccionario-datos

# %%
diccionario_involvement={1 :'Low',
2 :'Medium',
3 :'High',
4 :'Very High'}

df["JobInvolvement"]=df["JobInvolvement"].map(diccionario_involvement)

# %% [markdown]
# Hacemos lo mismo con JobSatisfaction

# %%
diccionario_satisfaction={1 :'Low',
2 :'Medium',
3 :'High',
4 :'Very High'}

df["JobSatisfaction"]=df["JobSatisfaction"].map(diccionario_satisfaction)

# %% [markdown]
# Procedemos de la misma forma con WorkLifeBalance

# %%
diccionario_balance={1 :'Bad',
2 :'Good',
3 :'Better',
4 :'Best'}

df["WorkLifeBalance"]=df["WorkLifeBalance"].map(diccionario_balance)

# %% [markdown]
# Mapeamos ahora "StockOptionLevel"

# %%
diccionario_stock={0 :'Bad',
1 :'Good',
2 :'Better',
3 :'Best'}

df["StockOptionLevel"]=df["StockOptionLevel"].map(diccionario_stock)

# %% [markdown]
# Formateamos también 'JobLevel'

# %%
diccionario_level={1 :'Intern',
2 :'Junior',
3 :'Senior',
4 :'Manager',
5:'Head'}

df["JobLevel"]=df["JobLevel"].map(diccionario_level)

# %%
df["PerformanceRating"].unique() #DECIDIR SI SE MAPEA O NOS LA CARGAMOS
# Out:
# array([3., 4.])

# %% [markdown]
# Ahora que hemos tratado nulos y formateado variables vamos a sacr de nuevo visualizaciones de nuestras distribuciones

# %%
visualizador = sp.Visualizador(df)

# %%
visualizador.plot_numericas(color="blue", tamano_grafica=(20, 15))

# %%
visualizador.plot_categoricas(color="red")
# Out:
# c:\Users\Administrador\Desktop\RCM\Proyecto8-Clasificacion\notebooks\modelo2\../..\src\soporte_preprocesamiento.py:184: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# Vamos a hacer una visualización de los outliers univariados.

# %%
visualizador.deteccion_outliers()

# %% [markdown]
# Los outliers los tratamos con detenimiento más adelante, vemos que hay varias columnas con outliers univariados, especialmente las que hacen referencia al sueldo al numero total de años trabajados, años en la cumpania y años desde la última promoción

# %% [markdown]
# Vamos a visualizar la relación de las variables predictoras con la variable respuesta Attrition

# %%
visualizador.plot_relacion("Attrition", tamano_grafica=(20, 30))

# %% [markdown]
# Las principales variables relacionadas con un attrition más alto incluyen:
#
# Satisfacción laboral y ambiental (EnvironmentSatisfaction, JobSatisfaction).
#
# Edad: Los empleados más jóvenes muestran mayor attrition.
#
# Viajes de negocios: Viajar con frecuencia puede ser un factor de rotación.
#
# Nivel de ingreso y opciones sobre acciones: Los beneficios económicos influyen significativamente.
#
# Antigüedad en la empresa y con el gerente actual: Los empleados nuevos o con poca relación con su gerente son más propensos a irse.

# %%
visualizador.correlacion(tamano_grafica = (7, 5))

# %% [markdown]
# Tenemos una correlación muy alta entre "PerformanceRating" y "PercentSalaryHike" y entre "YearsAtCompany" y "YearsWithCurrManager"

# %% [markdown]
# Eliminamos una de cada pareja.

# %%
df.drop(columns=["PerformanceRating","YearsWithCurrManager"], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EnvironmentSatisfaction  1573 non-null   object
#  1   JobSatisfaction          1573 non-null   object
#  2   WorkLifeBalance          1573 non-null   object
#  3   Age                      1573 non-null   float64
#  4   Attrition                1573 non-null   float64
#  5   BusinessTravel           1573 non-null   object
#  6   Department               1573 non-null   object
#  7   DistanceFromHome         1573 non-null   float64
#  8   Education                1573 non-null   object
#  9   EducationField           1573 non-null   object
#  10  Gender                   1573 non-null   object
#  11  JobLevel                 1573 non-null   object
#  12  JobRole                  1573 non-null   object
#  13  MaritalStatus            1573 non-null   object
#  14  MonthlyIncome            1573 non-null   float64
#  15  NumCompaniesWorked       1573 non-null   float64
#  16  PercentSalaryHike        1573 non-null   float64
#  17  StockOptionLevel         1573 non-null   object
#  18  TotalWorkingYears        1573 non-null   float64
#  19  TrainingTimesLastYear    1573 non-null   object
#  20  YearsAtCompany           1573 non-null   float64
#  21  YearsSinceLastPromotion  1573 non-null   float64
#  22  JobInvolvement           1573 non-null   object
# dtypes: float64(9), object(14)
# memory usage: 282.8+ KB

# %% [markdown]
# EDA terminado guardamos el picke con los datos obtenidos

# %%
df.to_pickle("../../datos/modelo3/datos_sin_nulos.pkl")
